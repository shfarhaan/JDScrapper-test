# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
service_obj = Service(r"D:\C Drive\Program Files\chromedriver-win64\chromedriver.exe")

driver = webdriver.Chrome(service = service_obj)
from selenium.webdriver.common.by import By
import time

# %%
driver.get("https://www.linkedin.com/home")

# %%
mail = "ADD_YOUR_EMAIL_HERE"
password = "ADD_YOUR_PASSWORD_HERE"

# %%
driver.find_element(By.XPATH, "//input[@type='text']").send_keys(mail)
driver.find_element(By.XPATH, "//input[@type='password']").send_keys(password)
driver.find_element(By.XPATH, "//button[@type='submit']").click()

# %%
# driver.get("https://www.linkedin.com/jobs/search/?currentJobId=3731078703&geoId=106215326&location=Bangladesh&origin=JOB_SEARCH_PAGE_SEARCH_BUTTON&refresh=true&sortBy=R")

# driver.get("https://www.linkedin.com/jobs/search/?currentJobId=3731574952&geoId=103363366&location=Dhaka%2C%20Bangladesh&origin=JOB_SEARCH_PAGE_LOCATION_AUTOCOMPLETE&refresh=true&sortBy=R")


driver.get("https://www.linkedin.com/jobs/search/?currentJobId=3733660954&f_E=1%2C2&f_TPR=r2592000&f_WT=2&geoId=103363366&location=Dhaka%2C%20Bangladesh&origin=JOB_SEARCH_PAGE_JOB_FILTER&refresh=true&sortBy=R")

# %%
import pandas as pd
df = pd.DataFrame()
ljob_title =[]
lname_location =[]
ljob_description =[]

# %%
page = 1

while True:
    try:
        page_numbers = driver.find_element(By.XPATH, f"//button[@aria-label='Page {page}']")
        page_numbers.click()
        time.sleep(3)

        # Using "find_elements" for searching multiple elements
        jobs_block = driver.find_elements(By.XPATH, "//ul[@class='scaffold-layout__list-container']/li")

        # executes JS to scroll the job divs into view
        for job in jobs_block:
            driver.execute_script("arguments[0].scrollIntoView();", job)
            time.sleep(1)

        jobs_link = driver.find_elements(By.XPATH, "//ul[@class='scaffold-layout__list-container']/li/div/div/div[1]/div[2]/div[1]/a")

        for link in jobs_link:
            link.click()
            time.sleep(1)

            job_title = driver.find_element(By.XPATH, "//h2[@class='t-24 t-bold job-details-jobs-unified-top-card__job-title']").text

            name_location = driver.find_element(By.XPATH, "//div[@class='job-details-jobs-unified-top-card__primary-description']").text

            job_description = driver.find_element(By.XPATH, "//div[@id='job-details']").text

            ljob_title.append(job_title)
            lname_location.append(name_location)
            ljob_description.append(job_description)

        # Increment the page number
        page += 1

    except NoSuchElementException as e:
        print(f"Error: {str(e)}")
        traceback.print_exc()
        # Handle the case where there are no more pages
        print(f"No more pages after page {page}")
        break
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[7], line 5
#       4 try:
# ----> 5     page_numbers = driver.find_element(By.XPATH, f"//button[@aria-label='Page {page}']")
#       6     page_numbers.click()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:738, in WebDriver.find_element(self, by, value)
#     736     value = f'[name="{value}"]'
# --> 738 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:344, in WebDriver.execute(self, driver_command, params)
#     343 if response:
# --> 344     self.error_handler.check_response(response)
#     345     response["value"] = self._unwrap_value(response.get("value", None))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//button[@aria-label='Page 25']"}
#   (Session info: chrome=118.0.5993.70); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF65DE17D32+55474]
# 	(No symbol) [0x00007FF65DD877E2]
# 	(No symbol) [0x00007FF65DC3E0EB]
# 	(No symbol) [0x00007FF65DC7EBAC]
# 	(No symbol) [0x00007FF65DC7ED2C]
# 	(No symbol) [0x00007FF65DCB9F77]
# 	(No symbol) [0x00007FF65DC9F19F]
# 	(No symbol) [0x00007FF65DCB7EF2]
# 	(No symbol) [0x00007FF65DC9EF33]
# 	(No symbol) [0x00007FF65DC73D41]
# 	(No symbol) [0x00007FF65DC74F84]
# 	GetHandleVerifier [0x00007FF65E17B772+3609330]
# 	GetHandleVerifier [0x00007FF65E1D1A90+3962384]
# 	GetHandleVerifier [0x00007FF65E1C9F1F+3930783]
# 	GetHandleVerifier [0x00007FF65DEB3CC6+694342]
# 	(No symbol) [0x00007FF65DD92238]
# 	(No symbol) [0x00007FF65DD8E4A4]
# 	(No symbol) [0x00007FF65DD8E5D2]
# 	(No symbol) [0x00007FF65DD7EE33]
# 	BaseThreadInitThunk [0x00007FFA1A967344+20]
# 	RtlUserThreadStart [0x00007FFA1C8426B1+33]
#
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 36
#      33     # Increment the page number
#      34     page += 1
# ---> 36 except NoSuchElementException as e:
#      37     print(f"Error: {str(e)}")
#      38     traceback.print_exc()
#
# NameError: name 'NoSuchElementException' is not defined

# %%
import traceback
from selenium.common.exceptions import NoSuchElementException

page = 1

while True:
    try:
        page_numbers = driver.find_element(By.XPATH, f"//button[@aria-label='Page {page}']")
        page_numbers.click()
        time.sleep(3)

        # Using "find_elements" for searching multiple elements
        jobs_block = driver.find_elements(By.XPATH, "//ul[@class='scaffold-layout__list-container']/li")

        # executes JS to scroll the job divs into view
        for job in jobs_block:
            driver.execute_script("arguments[0].scrollIntoView();", job)
            time.sleep(1)

        jobs_link = driver.find_elements(By.XPATH, "//ul[@class='scaffold-layout__list-container']/li/div/div/div[1]/div[2]/div[1]/a")

        for link in jobs_link:
            link.click()
            time.sleep(1)

            job_title = driver.find_element(By.XPATH, "//h2[@class='t-24 t-bold job-details-jobs-unified-top-card__job-title']").text

            name_location = driver.find_element(By.XPATH, "//div[@class='job-details-jobs-unified-top-card__primary-description']").text

            job_description = driver.find_element(By.XPATH, "//div[@id='job-details']").text

            ljob_title.append(job_title)
            lname_location.append(name_location)
            ljob_description.append(job_description)

        # Increment the page number
        page += 1

    except NoSuchElementException as e:
        # print(f"Error: {str(e)}")
        # traceback.print_exc()
        # Check if the error message contains "Unable to locate element"
        if "Unable to locate element" in str(e):
            print(f"No more pages after page {page}")
            break
# Out:
# No more pages after page 4

# %%
data = {"job_title" :ljob_title, "name_location" : lname_location, "job_description": ljob_description}

df = pd.DataFrame(data)
print(df)
# Out:
#                                              job_title  \
# 0                      Staff Machine Learning Engineer
# 1                 GM,Base Management (08 October 2023)
# 2                                Global Graduate - IDT
# 3                                        UX Researcher
# 4                                               Intern
# ..                                                 ...
# 594                              Senior Grants Manager
# 595  DE Jobs - The Estee Lauder Companies Non Brand...
# 596                                      Store Manager
# 597         Premium Customer Support Specialist (APAC)
# 598                                  Avaloq Consultant
#
#                                          name_location  \
# 0    Optimizely · Dhaka, Dhaka, Bangladesh Reposted...
# 1    Robi Axiata Limited · Bangladesh  6 days ago  ...
# 2    BAT · Dhaka, Dhaka, Bangladesh Reposted  1 wee...
# 3    Grameenphone Ltd · Bangladesh  4 days ago  · 1...
# 4    ADA · Dhaka, Bangladesh Reposted  19 hours ago...
# ..                                                 ...
# 594  International Rescue Committee · Cox’s Bazar, ...
# 595  buck global llc · Bangladesh  3 weeks ago  · 1...
# 596  Garima Interprises · Chattogram, Chattogram, B...
# 597  Deel · APAC Reposted  30 minutes ago  · 1,215 ...
# 598  Steenbok Pte Ltd · Bangladesh  5 months ago  ·...
#
#                                        job_description
# 0    About the job\nOptimizely is known for content...
# 1    About the job\nJob Purpose: Lead and manage th...
# 2    About the job\nBAT is evolving at pace - truly...
# 3    About the job\n\n\nJob Title: UX Researcher\n\...
# 4    About the job\nAbout ADA\n\nADA is a leading d...
# ..                                                 ...
# 594  About the job\nRequisition ID:  req43528\n\nJo...
# 595  About the job\nThis job is sourced from a job ...
# 596  About the job\nThis job is sourced from a job ...
# 597  About the job\nWho We Are And What We Do\n\nDe...
# 598  About the job\nOver the years, We have cultiva...
#
# [599 rows x 3 columns]

# %%
df
# Out:
#                                              job_title  \
# 0                    Global Graduate - Leaf Operations
# 1                     Senior Machine Learning Engineer
# 2    Finance and Operations Director - USAID Bangla...
# 3                                        UX Researcher
# 4                                               Intern
# ..                                                 ...
# 585                         Senior Full-Stack Engineer
# 586                 Senior Full-Stack (Back-End-Heavy)
# 587                                   Tech Lead - .Net
# 588                                         Tour Guide
# 589  Cost Controller - hotel Relocation to south sudan
#
#                                          name_location  \
# 0    BAT · Bangladesh Reposted  2 weeks ago  · 4,20...
# 1    Optimizely · Dhaka, Dhaka, Bangladesh Reposted...
# 2    RTI International · Bangladesh Reposted  1 wee...
# 3    Grameenphone Ltd · Bangladesh  4 days ago  · 1...
# 4    ADA · Dhaka, Bangladesh Reposted  17 hours ago...
# ..                                                 ...
# 585  Turing · Bangladesh  5 months ago  · 4 applicants
# 586    Turing · Bangladesh  1 month ago  · 1 applicant
# 587  Inivos · Dhaka, Dhaka, Bangladesh  2 months ag...
# 588  Garima Interprises · Bangladesh  1 month ago  ...
# 589  Business Umbrella - Management Consulting, Rec...
#
#                                        job_description
# 0    About the job\nBAT is evolving at a pace truly...
# 1    About the job\nOptimizely is known for content...
# 2    About the job\nOverview\n\nResearch Triangle I...
# 3    About the job\n\n\nJob Title: UX Researcher\n\...
# 4    About the job\nAbout ADA\n\nADA is a leading d...
# ..                                                 ...
# 585  About the job\nA NASDAQ-listed company utilizi...
# 586  About the job\nA fast-growing company that is ...
# 587  About the job\nWho is INIVOS?\n\nBased in Colo...
# 588  About the job\nThis job is sourced from a job ...
# 589  About the job\nWe are looking for one good can...
#
# [590 rows x 3 columns]

# %%
# Specify the file path where you want to save the CSV file
csv_file_path = 'JD_Bangladesh.csv'

# Write the DataFrame to a CSV file
df.to_csv(csv_file_path, index=False)

print(f"Data has been written to {csv_file_path}")
# Out:
# Data has been written to JD_Bangladesh.csv
